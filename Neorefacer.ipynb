# %% [markdown]
# <a href="https://colab.research.google.com/github/dilanvinod2002/ccbot/blob/main/Neorefacer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # #1 Clone

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/MechasAI/NeoRefacer.git
# %cd /content/drive/MyDrive/NeoRefacer
# Out:
# /content/drive/MyDrive
# fatal: destination path 'NeoRefacer' already exists and is not an empty directory.
# /content/drive/MyDrive/NeoRefacer

# %% [markdown]
# # #2 Requiremets

# %%
# !pip install ffmpeg_python==0.2.0
# !pip install imageio[ffmpeg]==2.37.0
# !pip install imagecodecs==2025.3.30
# !pip install gradio==5.22.0
# !pip install insightface==0.7.3
# !pip install --upgrade --force-reinstall numpy==2.0.1
# !pip install onnx==1.16.2
# !pip install onnxruntime-gpu==1.20.0
# !pip install opencv_python==4.7.0.72
# !pip install --upgrade --force-reinstall opencv-python-headless==4.12.0.88
# !pip install --upgrade scikit-image
# !pip install tqdm==4.67.1
# !pip install psutil==7.0.0
# !pip install ngrok==1.4.0
# !pip install pyfiglet==1.0.2
# codeformer dependencies
# torch==2.6.0
# torchvision==0.21.0
# !pip install gdown==5.2.0
# !pip install lpips==0.1.4
# Out:
# ...
#   Using cached numpy-2.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# ...

# %% [markdown]
# # #3 Main Code

# %%
# !python app.py --share_gradio
# Out:
# BasicSR Archs: Using CUDA backend.
# BasicSR: Using CUDA backend.
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/codeformer.pth" to /content/drive/MyDrive/NeoRefacer/weights/CodeFormer/codeformer.pth
#
# 100% 359M/359M [00:01<00:00, 210MB/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/detection_Resnet50_Final.pth" to /content/drive/MyDrive/NeoRefacer/weights/facelib/detection_Resnet50_Final.pth
#
# 100% 104M/104M [00:00<00:00, 182MB/s]
# Downloading: "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/parsing_parsenet.pth" to /content/drive/MyDrive/NeoRefacer/weights/facelib/parsing_parsenet.pth
#
# 100% 81.4M/81.4M [00:00<00:00, 150MB/s]
#     _   __           ____       ____
#    / | / /__  ____  / __ \___  / __/___ _________  _____
#   /  |/ / _ \/ __ \/ /_/ / _ \/ /_/ __ `/ ___/ _ \/ ___/
#  / /|  /  __/ /_/ / _, _/  __/ __/ /_/ / /__/  __/ /
# /_/ |_/\___/\____/_/ |_|\___/_/  \__,_/\___/\___/_/
#
#
# ...
